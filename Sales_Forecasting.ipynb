# %% [markdown]
# <a href="https://colab.research.google.com/github/tech-balaji-chennai/mdlc-simulation/blob/main/Sales_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SALES FORECASTING**
#
#
# ---

# %% [markdown]
# ## i) Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **1) PROBLEM DEFINITION**

# %% [markdown]
# ## **2) DESIGN SOLUTION**

# %% [markdown]
# ## **3) DATA COLLECTION**
#
# ### **i) Data Acquisition**
#
# *   Downloading large csv dataset from publicly accessible google drive url to output variable using gdown library

# %% [markdown]
# ### **i) Data Acquisition**
#
# *   Downloading large csv dataset from publicly accessible google drive url to output variable using gdown library

# %%
#google_drive_link = 'https://drive.google.com/file/d/1HjVRDEpdPcmlkDkHXNEPYY_OmEWR4C8T/view?usp=drive_link'
#gdown.download("https://drive.google.com/uc?id=YOUR_FILE_ID", output, quiet=False)
#gdown.download_folder("https://drive.google.com/drive/folders/YOUR_FOLDER_ID", quiet=False)

import gdown

file_id = "1HjVRDEpdPcmlkDkHXNEPYY_OmEWR4C8T"
url = f"https://drive.google.com/uc?id={file_id}"
output = 'amazon_products.csv'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1HjVRDEpdPcmlkDkHXNEPYY_OmEWR4C8T
# From (redirected): https://drive.google.com/uc?id=1HjVRDEpdPcmlkDkHXNEPYY_OmEWR4C8T&confirm=t&uuid=85617145-3111-4d59-a23f-fe9c184b79f8
# To: /content/amazon_products.csv
# 100%|██████████| 189M/189M [00:03<00:00, 50.0MB/s]
# 'amazon_products.csv'

# %% [markdown]
# ### **ii) Data Storage**
#
# *   Storing the acquired dataset to file system (or) database (if required)

# %% [markdown]
# ## **4) DATA PREPROCESSING**

# %% [markdown]
# ### **i) Data Ingestion**
#
# *   Loading output dataset into data variable

# %%
data = pd.read_csv(output)

# %% [markdown]
# ### **ii) Data Display**
#
# *   Displaying dataset

# %% [markdown]
# #### **a) Displaying 1st n no. of rows**

# %%
data.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1           1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2           2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3           3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4           4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#   main_category      sub_category  \
# 0    appliances  Air Conditioners
# 1    appliances  Air Conditioners
# 2    appliances  Air Conditioners
# 3    appliances  Air Conditioners
# 4    appliances  Air Conditioners
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
# ...

# %% [markdown]
# #### **b) Displaying last n no. of rows**

# %%
data.tail()
# Out:
#         Unnamed: 0                                               name  \
# 551580        1099                Adidas Regular Fit Men's Track Tops
# 551581        1100          Redwolf Noice Toit Smort - Hoodie (Black)
# 551582        1101     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)
# 551583        1102                                    Puma Men Shorts
# 551584        1103  Mothercare Printed Cotton Elastane Girls Infan...
#
#            main_category sub_category  \
# 551580  sports & fitness         Yoga
# 551581  sports & fitness         Yoga
# 551582  sports & fitness         Yoga
# 551583  sports & fitness         Yoga
# 551584  sports & fitness         Yoga
#
#                                                     image  \
# 551580  https://m.media-amazon.com/images/I/71tHAR9pIY...
# 551581  https://m.media-amazon.com/images/I/41pKrMZ5lQ...
# 551582  https://m.media-amazon.com/images/I/41n9u+zNSc...
# 551583  https://m.media-amazon.com/images/I/51LoWv5JDt...
# ...

# %% [markdown]
# #### **c) Displaying Information Of Data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 340680 entries, 0 to 551584
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      340680 non-null  int64
#  1   name            340680 non-null  object
#  2   main_category   340680 non-null  object
#  3   sub_category    340680 non-null  object
#  4   image           340680 non-null  object
#  5   link            340680 non-null  object
#  6   ratings         340680 non-null  object
#  7   no_of_ratings   340680 non-null  object
#  8   discount_price  340680 non-null  object
#  9   actual_price    340680 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 28.6+ MB

# %% [markdown]
# #### **d) Displaying Statistical Information Of Data**

# %%
data.describe()
# Out:
#           Unnamed: 0
# count  340680.000000
# mean     6075.853763
# std      5394.103490
# min         0.000000
# 25%      1167.000000
# 50%      4713.000000
# 75%      9481.000000
# max     19199.000000

# %% [markdown]
# ### **iii) Data Validation**

# %%
#Data validation code

# %% [markdown]
# ### **iv) Data Cleaning**

# %% [markdown]
# #### **a) Data Imputation**

# %%
result = data.isnull().sum()
print(result)
if(result.sum() == 0):
  print("No Missing Values")
else:
  data.dropna(inplace=True)
  print("Missing Values Are Dropped")
# Out:
# Unnamed: 0        0
# name              0
# main_category     0
# sub_category      0
# image             0
# link              0
# ratings           0
# no_of_ratings     0
# discount_price    0
# actual_price      0
# dtype: int64
# No Missing Values

# %%
#data.fillna(data.mean(), inplace=True)

# %% [markdown]
# #### **b) Data Deduplication**

# %%
result = data.duplicated().sum()
print(result)
if(result == 0):
  print("No Duplicates")
else:
  data.drop_duplicates(inplace=True)
# Out:
# 0
# No Duplicates

# %% [markdown]
# #### **c) Data Debugging**

# %%
#To display datatypes of all columns of dataframe
print(f"{data.dtypes}\n")

#To display datatypes of specified column(s) of dataframe
print(f"Before datatype conversion:\n{data[['discount_price', 'actual_price', 'ratings', 'no_of_ratings']].dtypes}\n")

#To convert column data type to any data type using astype() method
data['discount_price'] = data['discount_price'].astype(str).str.replace('₹', '', regex=False).str.replace(',', '').astype(float)
data['actual_price'] = data['actual_price'].astype(str).str.replace('₹', '', regex=False).str.replace(',', '').astype(float)
#data['discount_price'] = data['discount_price'].astype(str).str.replace(r'\₹', '', regex=True).str.replace(',', '').astype(float)
#data['actual_price'] = data['actual_price'].astype(str).str.replace(r'\₹', '', regex=True).str.replace(',', '').astype(float)

#To remove non-numeric values and convert to integer datatype by forcing invalid values to NaN instead of raising errors
data['ratings'] = pd.to_numeric(data['ratings'], errors='coerce').fillna(0).astype(int)
data['no_of_ratings'] = pd.to_numeric(data['no_of_ratings'], errors='coerce').fillna(0).astype(int)

print(f"After datatype conversion:\n{data[['discount_price', 'actual_price', 'ratings', 'no_of_ratings']].dtypes}\n")
# Out:
# Unnamed: 0         int64
# name              object
# main_category     object
# sub_category      object
# image             object
# link              object
# ratings           object
# no_of_ratings     object
# discount_price    object
# actual_price      object
# dtype: object
#
# Before datatype conversion:
# discount_price    object
# actual_price      object
# ratings           object
# no_of_ratings     object
# dtype: object
#
# After datatype conversion:
# discount_price    float64
# actual_price      float64
# ratings             int64
# no_of_ratings       int64
# dtype: object

# %% [markdown]
# #### **d) Data Splitting**
#
# *   For x, we will drop unwanted columns, such as 'image' and 'link'
# *   For y, we will estimate sales using proxy metrics
# *   For now, we will use no of ratings as a proxy metric since
#
#     i) It directly reflects customer engagement
#
#     ii) More ratings usually mean more sales
#
#     iii) It's numerical, making it easy for linear regression.
#
#     **Possible proxy metrics for target (y):**
#
# 1. **Number of Ratings**
# *   Indicates customer engagement and potential sales
# *   `y = data['no_of_ratings']`
#
# 2. **Weighted Popularity Score**
# *   Combines rating quality and customer interest
# *   `y = data['ratings'] * data['no_of_ratings']`
#
# 3. **Discount Factor**
# *   Measures the impact of discounts on attractiveness.
# *   `y = (data['actual_price'] - data['discount_price']) / data['actual_price']`
#
# 4. **Binary Popularity Label**
# *   Classifies products as "Popular" or "Unpopular"
# *   `y = (data['no_of_ratings'] > 50).astype(int)`
#
# 5. **Estimated Demand Score**
# *   Balances ratings, reviews, and price discounts
# *   `y = data['ratings'] * data['no_of_ratings'] / data['discount_price']`

# %%
x = data.drop(['Unnamed: 0', 'image', 'link', 'no_of_ratings'], axis=1)
y = data['no_of_ratings']
print(f"Datatypes of x variable:\n{x.dtypes}\n")
print(f"Datatypes of y variable:\n{y.dtypes}\n")

from sklearn.model_selection import train_test_split

#splitting dataset into 60% training, 20% validation and 20% testing data (x_train, x_val, x_test, y_train, y_val, y_test

#splitting data into 60% training data (x_train, y_train) and 40% temporary data (x_temp, y_temp)
x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.4, random_state=42)

#splitting temporary data (100% i.e. 40%) into 50% (i.e. 20%) validation data (x_val, y_val) and 50% (i.e. 20%) testing data (x_test, y_test)
#ensuring at least 2 samples in test set
if len(x_temp) <= 3:
  x_val = x_temp[:1]
  x_test = x_temp[1:]
  y_val = y_temp[:1]
  y_test = y_temp[1:]
else:
  x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

#To verify (or) confirm the shapes of x_train, x_test and y_train, y_test to be matched (m,n) and (m,)
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape)
# Out:
# Datatypes of x variable:
# name               object
# main_category      object
# sub_category       object
# ratings             int64
# discount_price    float64
# actual_price      float64
# dtype: object
#
# Datatypes of y variable:
# int64
#
# (204408, 6) (204408,) (68136, 6) (68136,) (68136, 6) (68136,)

# %% [markdown]
# ## **5) EXPLORATORY DATA ANALYSIS (EDA)**

# %%
#EDA code

# %% [markdown]
# ## **6) FEATURE ENGINEERING**

# %% [markdown]
# ### **i) Feature Creation**

# %%
#Feature creation code
#from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ### **ii) Feature Reduction**

# %%
x_train = x_train[['ratings', 'discount_price', 'actual_price']]
x_val = x_val[['ratings', 'discount_price', 'actual_price']]
x_test = x_test[['ratings', 'discount_price', 'actual_price']]

# %% [markdown]
# ### **iii) Feature Transformation**

# %% [markdown]
# #### **a) Feature Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
for col in x_train.columns:
  if x_train[col].dtype == 'object':
    x_train[col] = encoder.fit_transform(x_train[col])
    x_val[col] = encoder.transform(x_val[col])
    x_test[col] = encoder.transform(x_test[col])

# %% [markdown]
# #### **b) Feature Binning**

# %%
from sklearn.preprocessing import KBinsDiscretizer

# %% [markdown]
# #### **c) Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(x_test)

# %% [markdown]
# #### **d) Feature Normalization**

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## **7) ML Model Selection**

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %% [markdown]
# ## **8) ML Model Training**

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## **9) ML Model Tuning**

# %% [markdown]
# ### **i) Hyperparameter Tuning**

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'fit_intercept': [True, False]}
grid_search = GridSearchCV(estimator = model, param_grid = param_grid, cv=min(5, len(x_val)), scoring='r2', error_score='raise')

try:
    grid_search.fit(x_val, y_val)
except Exception as e:
    print(f"Error during hyperparameter tuning: {e}")

print(grid_search.best_params_)
# Out:
# {'fit_intercept': False}

# %% [markdown]
# ### **ii) Model Selection**

# %%
model = grid_search.best_estimator_

# %% [markdown]
# ### **iii) Model Validation**

# %%
y_val_pred = model.predict(x_val)
print(f"Predicted Target:\n{y_val_pred}\n")
print(f"Actual Target:\n{y_val}\n")
# Out:
# Predicted Target:
# [-3.95809688 -3.93134342 -4.01160409 ...  4.91333536 -3.01955551
#  -4.0667224 ]
#
# Actual Target:
# 421047      2
# 352364     67
# 419724    425
# 167960     17
# 344274    420
#          ...
# 49849       3
# 39706     133
# 535450      1
# 174366     73
# 264612     18
# Name: no_of_ratings, Length: 68136, dtype: int64

# %% [markdown]
# ### **iv) Model Performance Calculation**

# %%
from sklearn.metrics import r2_score, mean_squared_error

r2_val = r2_score(y_val, y_val_pred)
mse_val = mean_squared_error(y_val, y_val_pred)
print(f"R2 score = {r2_val * 100:.4f}%")
print(f"MSE = {mse_val * 100:.4f}%")

if r2_val < 0.90:
  print("Model is not up to the level...\n")
  print(r2_val)
# Out:
# R2 score = -23.3137%
# MSE = 3309285.2177%
# Model is not up to the level...
#
# -0.2331371411252483

# %% [markdown]
# ## **10) ML Model Evaluation**

# %% [markdown]
# ### **i) Final Model Testing**

# %%
y_test_pred = model.predict(x_test)
print(f"Predicted Target:\n{y_test_pred}\n")
print(f"Actual Target:\n{y_test}\n")
# Out:
# Predicted Target:
# [ 4.94008967 -1.45388709 13.86556755 ...  4.46953653  6.46508931
#  -3.66380039]
#
# Actual Target:
# 440120     4
# 350572     6
# 504738     1
# 147940    22
# 243776     0
#           ..
# 454773     2
# 78054     52
# 76613     48
# 68293     10
# 122303    86
# Name: no_of_ratings, Length: 68136, dtype: int64

# %% [markdown]
# ### **ii) Final Model Performance Calculation**

# %%
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
print(f"R2 score = {r2_test*100:.4f}%")
print(f"MSE = {mse_test*100:.4f}%")

if r2_test >= 0.99:
  print("Model's performance: perfect")
elif r2_test > 0.90:
  print("Model's performance: outstanding")
elif r2_test == 0.90:
  print("Model's performance: excellent")
elif r2_test > 0.80:
    print("Model's performance: very strong")
elif r2_test == 0.80:
    print("Model's performance: strong")
elif r2_test > 0.50: #above average (or) superpar
    print("Model's performance: moderate")
elif r2_test == 0.50: #at average (or) par
    print("Model's performance: average")
elif r2_test > 0.20: #below average (or) subpar
    print("Model's performance: fair")
elif r2_test == 0.20:
    print("Model's performance: weak")
elif r2_test > 0.10:
    print("Model's performance: very weak")
elif r2_test == 0.10:
    print("Model's performance: terrible")
elif r2_test > 0.01:
    print("Model's performance: awful")
elif r2_test == 0.01:
    print("Model's performance: imperfect")
else:
    print("Model's performance: Useless")
# Out:
# R2 score = -23.2880%
# MSE = 3378725.8822%
# Model's performance: Useless

# %% [markdown]
# ## **11) ML Model Deployment**

# %% [markdown]
# ## **12) ML Model Monitoring And Maintenance**
